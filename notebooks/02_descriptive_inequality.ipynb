# %% [markdown]
# # 02 — Descriptive statistics and inequality
# Computes annual statistics, Gini coefficients, histograms, and Lorenz curves.

# %%
from pathlib import Path
from pnad_income.io import load_refined_panel
from pnad_income.inequality import summary_statistics
from pnad_income.plotting import plot_histograms, plot_lorenz_by_year

REFINED_ROOT = Path("../data/processed")
panel = load_refined_panel(REFINED_ROOT)
panel.head()

# %%
stats = summary_statistics(panel)
stats

# %%
fig_hist = plot_histograms(panel, value_col="income")

# %%
fig_lorenz = plot_lorenz_by_year(panel, value_col="income")
