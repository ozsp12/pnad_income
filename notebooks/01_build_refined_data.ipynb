# %% [markdown]
# # 01 — Build refined annual datasets
# Reads the fixed-width PNAD files using metadata and writes one standardized Parquet file per available year. VD4020 is retained for 2016–2025.

# %%
from pathlib import Path
from pnad_income.io import build_refined_datasets

RAW_ROOT = Path("../data/raw")
REFINED_ROOT = Path("../data/processed")

# %%
# Uncomment after placing the raw IBGE files under data/raw.
# written = build_refined_datasets(RAW_ROOT, REFINED_ROOT)
# written[:5]
