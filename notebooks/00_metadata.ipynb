# %% [markdown]
# # 00 — Metadata and survey map
# The metadata table is the single source of truth for variable positions, missing-value sentinels, monetary adjustment factors, and source URLs.

# %%
from pnad_income.config import load_metadata
metadata = load_metadata()
metadata

# %%
metadata.loc[metadata.available, ["year", "survey", "income_variable", "effective_income_variable", "raw_file_pattern"]]
